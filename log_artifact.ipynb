# %%
# делаем import необходимых библиотек
import os

import mlflow

# устанавливаем локальное хранилище для наших экспериментов
# хранилище должно быть такое же, как и при запуске сервиса
mlflow.set_tracking_uri('file:./mlflow_experiments_store')
#mlflow.set_experiment("test")

# %%
# получаем id эксеримента, который создаётся по умолчанию
# эксперимент по умолчанию называется Default
experiment_id = mlflow.get_experiment_by_name("test").experiment_id

# %%
with mlflow.start_run(run_name='test', experiment_id=experiment_id) as run:
    run_id = run.info.run_id
    mlflow.log_metric("test_metric", 0)
    mlflow.log_artifact("test_artifact.txt", "test_artifact")

print(f"Run id запуска: {run_id}")
# Out:
# Run id запуска: 28f67d88c45d4c08847add3211ce3e4e

# %%
# !ls mlflow_experiments_store/970891290514471451/{run_id}/metrics
# Out:
# test_metric

# %%
# !cat mlflow_experiments_store/970891290514471451/{run_id}/artifacts/test_artifact/test_artifact.txt
# Out:
# test_artifact

# %%
assert os.path.exists("mlflow_experiments_store_sqlite")
assert os.path.exists("mydb.sqlite")

# %%
import os

import mlflow

mlflow.set_tracking_uri('http://0.0.0.0:5000')

# получаем id эксперимента, который создаётся по умолчанию
# эксперимент по умолчанию называется Default
experiment_id = mlflow.get_experiment_by_name("Def").experiment_id

# %%
with mlflow.start_run(run_name="Def1", experiment_id=experiment_id) as run:
    run_id = run.info.run_id
    
    mlflow.log_metric("test_metric_sqlite", 0)
    mlflow.log_artifact("test_artifact.txt", "test_artifact_sqlite00")

# %%
# проверим, что наши данные сохранились в локальной папке, а также создалась база данных SQLite
assert os.path.exists("mlflow_experiments_store_sqlite")
assert os.path.exists("mydb.sqlite")

# %%
pip install psycopg && pip install 'psycopg[binary]'
# Out:
# Collecting psycopg
#   Using cached psycopg-3.3.2-py3-none-any.whl (212 kB)
# Requirement already satisfied: typing-extensions>=4.6 in /home/mle-user/mle_projects/.venv/lib/python3.10/site-packages (from psycopg) (4.8.0)
# Installing collected packages: psycopg
# Successfully installed psycopg-3.3.2
# Requirement already satisfied: psycopg[binary] in /home/mle-user/mle_projects/.venv/lib/python3.10/site-packages (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6 in /home/mle-user/mle_projects/.venv/lib/python3.10/site-packages (from psycopg[binary]) (4.8.0)
# Collecting psycopg-binary==3.3.2
#   Downloading psycopg_binary-3.3.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 18.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: psycopg-binary
# Successfully installed psycopg-binary-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
